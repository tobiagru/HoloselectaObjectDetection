# %% [markdown]
# # Mount Google Drive to access files

# %%
#!apt-get install tree
#!tree --help
#!tree --du -h gdrive/My\ Drive/Masterarbeit
# !du -h --max-depth=1 gdrive/My\ Drive/
# Out:
# 2.9M	gdrive/My Drive/Colab Notebooks
# 31G	gdrive/My Drive/Masterarbeit
# 903K	gdrive/My Drive/Hyve
# 31G	gdrive/My Drive/

# %% [markdown]
# ---
# # Imports & Config

# %%
import os

class FLAGS_IC:
    # directories & files for tmp storage
    base_dir = "/content/gdrive/My Drive/Masterarbeit/ImageClassification"
    image_dir = base_dir + "/ImagePatches"


class FLAGS_OD:
    base_dir = "/content/gdrive/My Drive/Masterarbeit/ObjectDetection"
    
    image_dir = os.path.join(base_dir, "Images")
  

class FLAGS_TB:
    # a temporary folder to run tensorboard on, doesn't seem to run on a Gdrive mounted folder
    tmp_graph_dir = "/content/summaries"

    # how many images fit horizontally in an image mosaic
    tb_mosaic_width = 5

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Connect to GPU

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Mount GDrive

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Pretty Print

# %%
from pprint import PrettyPrinter

pp = PrettyPrinter(indent=2)
def print(kwargs):
  pp.pprint(kwargs)

# %% [markdown]
# # All Purpose Functions

# %%
import os
import tensorflow as tf

def get_xml_files(root_dir, selected_folders=None):
  """Gets all xml files recursively inside the root directory
  and returns the file names with the path
  Args:
    root_dir: root directory as string
    selected_folders: list of folder names which should only be
        used for the dataset. If None will use all.
  Returns:
    list of tuples with file_name and path_name relative from
        root_dir
  """
  file_list = []
  
  root_f = root_dir.split(os.sep)
  for path, _, files in tf.gfile.Walk(root_dir):
    path_f = path.split(os.sep)
    if not selected_folders is None and not \
        any(s_folder in path_f for s_folder in selected_folders):
      continue
    for file in files:
      if file.split(".")[-1] == "xml":
        rel_path = [f for f in path_f if f not in root_f]
        rel_path = os.sep.join(rel_path)
        file_list.append((file, rel_path))
  
  return file_list

# %%
import os
from bs4 import BeautifulSoup

def load_annotation(file_path):
  """
  Load annotation file for a given image and parse xml to dict.
  Args:
    img_name: string of the image name.
    infos: dict with information that should be appended to image dict
  Returns:
    dict of the image with all infos
  """
  xml = ""
  with open(file_path, 'r') as f:
    xml = f.readlines()
  xml = ''.join([line.strip('\t') for line in xml])
  bs = BeautifulSoup(xml)
  image_filename = os.path.join(*(file_path.split(os.sep)[:-1]))
  filename = bs.filename.string.replace("\n","").replace("\t","").replace(" ","")
  image_filename = os.path.join(image_filename, filename)
  image_filename = image_filename.replace("content/","")
  image = {"filename": image_filename.replace("\n",""),
           "size": {"width": int(bs.size.width.string),
                    "height": int(bs.size.height.string)},
           "objects": []}

  for ob in bs.find_all("object"):
    name = ob.find('name').string.replace("\n","").replace("\t","").replace(" ","")
          
    obj = {"name": name,
           "bndbox":{"xmin": int(ob.bndbox.xmin.string),
                     "xmax": int(ob.bndbox.xmax.string),
                     "ymin": int(ob.bndbox.ymin.string),
                     "ymax": int(ob.bndbox.ymax.string)},
           "pose":ob.pose.string,
           "truncated": bool(ob.truncated.string),
           "difficult": bool(ob.difficult.string)}
    image["objects"].append(obj)
  return image

# %%
def rotate_box(obj, height_old):
  xmin_tmp = height_old - obj["bndbox"]["ymax"]
  xmax_tmp = height_old - obj["bndbox"]["ymin"]
  ymin_tmp = obj["bndbox"]["xmin"]
  ymax_tmp = obj["bndbox"]["xmax"]
  obj["bndbox"]["xmin"] = xmin_tmp
  obj["bndbox"]["xmax"] = xmax_tmp
  obj["bndbox"]["ymin"] = ymin_tmp
  obj["bndbox"]["ymax"] = ymax_tmp

# %%
import cv2

def rotate_img(image):
  img = cv2.imread(image["filename"], 1)
  M = cv2.getRotationMatrix2D((image["size"]["height"]/2,image["size"]["width"]/2), 270, 1)
  rotated = cv2.warpAffine(img, M, (image["size"]["height"] ,image["size"]["width"]))
  cv2.imwrite(image["filename"], img)
  
  width_tmp = image["size"]["height"]
  height_tmp = image["size"]["width"]
  image["size"]["width"] = width_tmp
  image["size"]["height"] = height_tmp

# %%
import os

def append_basic(xml_list, image):
  xml_list.append("<folder>{}</folder>".format(image["filename"].split(os.sep)[-2]))
  xml_list.append("<filename>{}</filename>".format(image["filename"].split(os.sep)[-1]))
  xml_list.append("<path>{}</path>".format(image["filename"]))
  xml_list.append("<source>\n\t<database>Unknown</database>\n</source>")
  xml_list.append("<size>")
  xml_list.append("\t<width>{}</width>".format(image["size"]["width"]))
  xml_list.append("\t<height>{}</height>".format(image["size"]["height"]))
  xml_list.append("\t<depth>{}</depth>".format(3))
  xml_list.append("</size>")
  xml_list.append("<segmented>0</segmented>")

# %%
def append_obj(xml_list, obj):
  xml_list.append("<object>")
  xml_list.append("\t<name>{}</name>".format(obj["name"]))
  xml_list.append("\t<pose>Unspecified</pose>")
  xml_list.append("\t<truncated>0</truncated>")
  xml_list.append("\t<difficult>0</difficult>")
  xml_list.append("\t<bndbox>")
  xml_list.append("\t\t<xmin>{}</xmin>".format(obj["bndbox"]["xmin"]))
  xml_list.append("\t\t<ymin>{}</ymin>".format(obj["bndbox"]["ymin"]))
  xml_list.append("\t\t<xmax>{}</xmax>".format(obj["bndbox"]["xmax"]))
  xml_list.append("\t\t<ymax>{}</ymax>".format(obj["bndbox"]["ymax"]))
  xml_list.append("\t</bndbox>")
  xml_list.append("</object>")

# %%
from PIL import Image

def extract_patches(image):
  im=Image.open(image["filename"])
  
  for obj in image["objects"]:
    im=Image.open(image["filename"])

    bndbox = obj["bndbox"]
    bndbox = (bndbox["xmin"], bndbox["ymin"], bndbox["xmax"], bndbox["ymax"])

    im2=im.crop(bndbox)

    im2.save(".".join(image["filename"].split(".")[:-1]) + "_" + obj["name"] + ".png")

# %% [markdown]
# # Replace Labels

# %%
repl = {"can": "dose",
        "bottle": "flasche",
        "-": "_",
        "ö": "oe",
        "ä": "ae",
        "ü": "ue",}
repl_cls = {
            "coke___50__54491472": "coke__flasche_50__54491472",
}


files = get_xml_files(FLAGS_OD.image_dir, selected_folders=["_Automat"])
print(FLAGS_OD.image_dir)
print(len(files))
for file, path in files:
  print("working on:", file)
  xml_file = os.path.join(FLAGS_OD.image_dir, path, file)
  image = load_annotation(xml_file)
  xml_list = ["<annotation>"]
  append_basic(xml_list, image)
  
  for obj in image["objects"]:
    for key, val in repl.items():
      obj["name"] = obj["name"].replace(key,val)
    for key, val in repl_cls.items():
      if key in obj["name"]:
        obj["name"] = val
    append_obj(xml_list, obj)
    
  xml_list.append("</annotation>")    
  with open(xml_file, "w+") as file:
    file.write("\n".join(xml_list))
# Out:
# /content/gdrive/My Drive/Masterarbeit/ObjectDetection/Images
# 295
# working on: DSC01628.xml
# working on: DSC01630.xml
# working on: DSC01631.xml
# working on: DSC01629.xml
# working on: IMG_20181218_173039.xml
# working on: DSC01646.xml
# working on: IMG_20181218_175507.xml
# working on: IMG_20181218_170655.xml
# working on: DSC01627.xml
# working on: DSC01633.xml
# working on: IMG_20181218_171607.xml
# working on: DSC01655.xml
# working on: IMG_20181218_172857.xml
# working on: DSC01667.xml
# working on: DSC01651.xml
# working on: IMG_20181218_170243.xml
# working on: IMG_20181218_175503.xml
# working on: DSC01635.xml
# working on: IMG_20181218_171805.xml
# working on: DSC01671.xml
# working on: DSC01669.xml
# working on: DSC01638.xml
# working on: DSC01672.xml
# working on: IMG_20181218_174605.xml
# working on: IMG_20181218_170459.xml
# working on: DSC01675.xml
# working on: IMG_20181218_172432.xml
# working on: IMG_20181218_170648.xml
# working on: DSC01678.xml
# working on: DSC01642.xml
# working on: DSC01679.xml
# working on: 20190111_115057_HoloLens.xml
# working on: 20190111_115157_HoloLens.xml
# working on: DSC01663.xml
# working on: 20190111_115106_HoloLens.xml
# working on: 20190111_115203_HoloLens.xml
# working on: 20190111_115116_HoloLens.xml
# working on: 20190111_115136_HoloLens.xml
# working on: IMG_20181218_173031.xml
# working on: 20190111_111641_HoloLens.xml
# working on: 20190111_115218_HoloLens.xml
# working on: 20190111_115150_HoloLens.xml
# working on: 20190111_111648_HoloLens.xml
# working on: 20190111_115234_HoloLens.xml
# working on: IMG_20181218_171800.xml
# working on: 20190111_111611_HoloLens.xml
# working on: 20190111_111656_HoloLens.xml
# working on: 20190111_111616_HoloLens.xml
# working on: IMG_20181218_172844.xml
# working on: 20190111_111715_HoloLens.xml
# working on: IMG_20181218_172433.xml
# working on: 20190111_111631_HoloLens.xml
# working on: IMG_20181218_173035.xml
# working on: 20190111_111725_HoloLens.xml
# working on: 20190111_111600_HoloLens.xml
# working on: 20190111_115017_HoloLens.xml
# working on: 20190111_111623_HoloLens.xml
# working on: 20190111_111703_HoloLens.xml
# working on: 20190111_111731_HoloLens.xml
# working on: IMG_20181218_171749.xml
# working on: 20190111_115003_HoloLens.xml
# working on: 20190111_115010_HoloLens.xml
# working on: 20190111_115042_HoloLens.xml
# working on: IMG_20181218_172438.xml
# working on: 20190111_115122_HoloLens.xml
# working on: 20190111_115028_HoloLens.xml
# working on: 20190111_115129_HoloLens.xml
# working on: 20190111_115050_HoloLens.xml
# working on: IMG_20181218_170635.xml
# working on: 20190111_115143_HoloLens.xml
# working on: IMG_20181218_174557.xml
# working on: IMG_20181218_175423.xml
# working on: IMG_20181218_174559.xml
# working on: IMG_20181218_171555.xml
# working on: IMG_20181218_174507.xml
# working on: IMG_20181218_170247.xml
# working on: IMG_20181218_172442.xml
# working on: IMG_20181218_174601.xml
# working on: IMG_20181218_173705.xml
# working on: IMG_20181218_173702.xml
# working on: IMG_20181218_170649.xml
# working on: IMG_20181218_171740.xml
# working on: IMG_20181218_170645.xml
# working on: IMG_20181218_175338.xml
# working on: IMG_20181218_171743.xml
# working on: IMG_20181218_165657.xml
# working on: IMG_20181218_175420.xml
# working on: IMG_20181218_173655.xml
# working on: IMG_20181218_173657.xml
# working on: IMG_20181218_172854.xml
# working on: IMG_20181218_174511.xml
# working on: IMG_20181218_172846.xml
# working on: IMG_20181218_175501.xml
# working on: IMG_20181218_172839.xml
# working on: IMG_20181218_170046.xml
# working on: IMG_20181218_171755.xml
# working on: IMG_20181218_170510.xml
# working on: IMG_20181218_171753.xml
# working on: IMG_20181218_175340.xml
# working on: IMG_20181218_173700.xml
# working on: IMG_20181218_172856.xml
# working on: IMG_20181218_175334.xml
# working on: IMG_20181218_165931.xml
# working on: IMG_20181218_175504.xml
# working on: IMG_20181218_173033.xml
# working on: IMG_20181218_165652.xml
# working on: IMG_20181218_172841.xml
# working on: IMG_20181218_170657.xml
# working on: IMG_20181218_175425.xml
# working on: IMG_20190125_113835.xml
# working on: IMG_20181218_171802.xml
# working on: IMG_20190125_113830.xml
# working on: IMG_20181218_172849.xml
# working on: IMG_20181218_171604.xml
# working on: IMG_20181218_174603.xml
# working on: IMG_20181218_165757.xml
# working on: IMG_20190125_113823.xml
# working on: IMG_20181218_130011.xml
# working on: IMG_20181218_130005.xml
# working on: IMG_20181218_130002.xml
# working on: IMG_20181218_170508.xml
# working on: IMG_20181218_125954.xml
# working on: 20190125_114246.xml
# working on: IMG_20190306_173403.xml
# working on: DSC01632.xml
# working on: DSC01634.xml
# working on: DSC01639.xml
# working on: DSC01640.xml
# working on: DSC01641.xml
# working on: DSC01643.xml
# working on: DSC01644.xml
# working on: DSC01645.xml
# working on: DSC01647.xml
# working on: DSC01652.xml
# working on: DSC01653.xml
# working on: DSC01656.xml
# working on: DSC01657.xml
# working on: DSC01658.xml
# working on: DSC01659.xml
# working on: DSC01660.xml
# working on: DSC01661.xml
# working on: DSC01662.xml
# working on: DSC01664.xml
# working on: DSC01665.xml
# working on: DSC01666.xml
# working on: DSC01668.xml
# working on: DSC01670.xml
# working on: DSC01673.xml
# working on: DSC01674.xml
# working on: DSC01676.xml
# working on: DSC01677.xml
# working on: DSC01680.xml
# working on: DSC01681.xml
# working on: IMG_20181218_164606.xml
# working on: IMG_20181218_164608.xml
# working on: IMG_20181218_165501.xml
# working on: IMG_20181218_165504.xml
# working on: IMG_20181218_165508.xml
# working on: IMG_20181218_165513.xml
# working on: IMG_20181218_165646.xml
# working on: IMG_20181218_165648.xml
# working on: IMG_20181218_165753.xml
# working on: IMG_20181218_165800.xml
# working on: IMG_20181218_165804.xml
# working on: IMG_20181218_165922.xml
# working on: IMG_20181218_165934.xml
# working on: IMG_20181218_170040.xml
# working on: IMG_20181218_170043.xml
# working on: IMG_20181218_170049.xml
# working on: IMG_20181218_170238.xml
# working on: IMG_20181218_170502.xml
# working on: IMG_20181218_170513.xml
# working on: IMG_20181218_170633.xml
# working on: IMG_20181218_171737.xml
# working on: IMG_20181218_172430.xml
# working on: IMG_20181218_172440.xml
# working on: IMG_20181218_172859.xml
# working on: IMG_20181218_173028.xml
# working on: IMG_20181218_173652.xml
# working on: IMG_20181218_174501.xml
# working on: IMG_20181218_175259.xml
# working on: IMG_20181218_175301.xml
# working on: IMG_20181218_175304.xml
# working on: IMG_20181218_175308.xml
# working on: IMG_20181218_175311.xml
# working on: IMG_20181218_175416.xml
# working on: IMG_20181218_175457.xml
# working on: IMG_20190206_170142.xml
# working on: IMG_20190206_170434.xml
# working on: IMG_20190206_170436.xml
# working on: IMG_20190206_170446.xml
# working on: IMG_20190206_170448.xml
# working on: IMG_20190206_170606.xml
# working on: IMG_20190206_170619.xml
# working on: IMG_20190206_170714.xml
# working on: IMG_20190206_170716.xml
# working on: IMG_20190206_174446.xml
# working on: IMG_20190206_174702.xml
# working on: IMG_20190206_174705.xml
# working on: IMG_20190206_174757.xml
# working on: IMG_20190206_174800.xml
# working on: IMG_20190206_174819.xml
# working on: IMG_20190206_174822.xml
# working on: IMG_20190206_174852.xml
# working on: IMG_20190206_174855.xml
# working on: IMG_20190206_175054.xml
# working on: IMG_20190206_175058.xml
# working on: IMG_20190206_175100.xml
# working on: IMG_20190206_175511.xml
# working on: IMG_20190206_175516.xml
# working on: IMG_20190206_175715.xml
# working on: IMG_20190206_175717.xml
# working on: IMG_20190206_175720.xml
# working on: IMG_20190206_175724.xml
# working on: IMG_20190206_175751.xml
# working on: IMG_20190206_175755.xml
# working on: IMG_20190206_175758.xml
# working on: IMG_20190206_175803.xml
# working on: IMG_20190206_175805.xml
# working on: IMG_20190206_175853.xml
# working on: IMG_20190206_175857.xml
# working on: IMG_20190206_175859.xml
# working on: IMG_20190306_104622.xml
# working on: IMG_20190306_172008.xml
# working on: IMG_20190307_152732.xml
# working on: IMG_20190307_152734.xml
# working on: IMG_20190402_110254.xml
# working on: IMG_20190409_112103.xml
# working on: IMG_20190409_121733.xml
# working on: IMG_20190430_105750.xml
# working on: IMG_20190430_105754.xml
# working on: IMG_20190430_105805.xml
# working on: IMG_20190430_105808.xml
# working on: IMG_20190430_105959.xml
# working on: IMG_20190430_110010.xml
# working on: IMG_20190430_110145.xml
# working on: IMG_20190430_110149.xml
# working on: IMG_20190430_110153.xml
# working on: IMG_20190430_110157.xml
# working on: IMG_20190430_110231.xml
# working on: IMG_20190430_110329.xml
# working on: IMG_20190430_110417.xml
# working on: IMG_20190430_111230.xml
# working on: IMG_20190430_111456.xml
# working on: IMG_20190430_111521.xml
# working on: IMG_20190430_111555.xml
# working on: IMG_20190430_111611.xml
# working on: IMG_20190430_111818.xml
# working on: IMG_20190430_111942.xml
# working on: IMG_20190430_111949.xml
# working on: IMG_20190502_093212.xml
# working on: IMG_20190502_093643.xml
# working on: IMG_20190502_093929.xml
# working on: IMG_20190502_093933.xml
# working on: IMG_20190502_093957.xml
# working on: IMG_20190502_094330.xml
# working on: IMG_20190502_094333.xml
# working on: IMG_20190502_171330.xml
# working on: IMG_20190502_171332.xml
# working on: IMG_20190502_180150.xml
# working on: IMG_20190306_164958.xml
# working on: 20190125_113931.xml
# working on: IMG_20190125_133951.xml
# working on: 20190125_113928.xml
# working on: IMG_20190306_171814.xml
# working on: IMG_20190206_120945.xml
# working on: IMG_20190306_110658.xml
# working on: IMG_20190306_171256.xml
# working on: IMG_20190306_171253.xml
# working on: IMG_20190306_172403.xml
# working on: IMG_20190306_172410.xml
# working on: 20190125_114244.xml
# working on: IMG_20190306_173149.xml
# working on: IMG_20190306_173405.xml
# working on: IMG_20190306_173408.xml
# working on: IMG_20190306_173147.xml
# working on: IMG_20190306_170622.xml
# working on: IMG_20190306_170619.xml
# working on: 20190125_113923.xml
# working on: 20190125_113909.xml
# working on: 20190103_103704.xml
# working on: IMG_20190206_170138.xml
# working on: IMG_20190206_170217.xml
# working on: IMG_20190206_170222.xml
# working on: IMG_20190206_170257.xml
# working on: IMG_20190306_171957.xml
# working on: IMG_20190306_172001.xml
# working on: IMG_20190306_172745.xml
# working on: IMG_20190306_172748.xml
# working on: IMG_20190306_172751.xml
# working on: IMG_20190306_171808.xml
# working on: IMG_20190306_170625.xml
# working on: IMG_20190306_173145.xml
# working on: IMG_20190306_165020.xml
# working on: IMG_20190206_170337.xml

# %% [markdown]
# # per image patch cleaning

# %%
from PIL import Image
from IPython.display import display, clear_output
import ipywidgets as widgets
import time
import os
import tensorflow as tf
from bs4 import BeautifulSoup

drinks = [
  "3068320353500",
  "76404160",
  "7610335002575"
  "9120025930135",
  "54491472",
  "5449238",
  "5449000131836",
  "40822938",
  "5449000235947",
  "5449000236623",
  "54490840",
  "7610057001078",
  "7610057012456",
  "90162909",
  "90162800",
  "7610097112079",
  "7610097111072",
  "7610335001530",
  "305764335648"
]

button = widgets.Button(description="Next")
radio = widgets.RadioButtons(
    options=['front', 'back', 'side'],
    description='pose:',
    disabled=False
)

cnt_out = widgets.Output()
img_out = widgets.Output()
display(cnt_out)
display(img_out)
display(radio)
display(button)


def load_annotation(file_path):
    """
    Load annotation file for a given image.
    Args:
        img_name (string): string of the image name, relative to
            the image directory.
    Returns:
        BeautifulSoup structure: the annotation labels loaded as a
            BeautifulSoup data structure
    """
    xml = ""
    with open(file_path) as f:
        xml = f.readlines()
    xml = ''.join([line.strip('\t') for line in xml])
    return BeautifulSoup(xml, "lxml")

def get_xml_files(root_dir, selected_folders=None):
    """Gets all xml files recursively inside the root directory
    and returns the file names with the path
    Args:
    root_dir: root directory as string
    selected_folders: list of folder names which should only be
        used for the dataset. If None will use all.
    Returns:
    list of tuples with file_name and path_name relative from
        root_dir
    """
    file_list = []

    root_f = root_dir.split(os.sep)
    for path, _, files in tf.gfile.Walk(root_dir):
        path_f = path.split(os.sep)
        if not selected_folders is None and not any(s_folder in path_f for s_folder in selected_folders):
            continue
        for file in files:
            if file.split(".")[-1] == "xml":
                rel_path = [f for f in path_f if f not in root_f]
                rel_path = os.path.join(*rel_path)
                file_list.append((file, rel_path))

    return file_list


def image_iter():
    image_dir = os.path.join(os.getcwd(),FLAGS_OD.image_dir)
    xmlfiles = get_xml_files(image_dir)
    it = 0
    for file_name, rel_path in xmlfiles:
        with cnt_out:
            clear_output()
            print(it, file_name)
        filename = os.path.join(image_dir, rel_path, file_name)
        pv = load_annotation(filename)
        img_filename = pv.annotation.filename.string.replace(" ","").replace("\n","")
        pil_im = Image.open(os.path.join(image_dir, rel_path, img_filename))
        for ob in pv.find_all("object"):
            gtin = ob.find('name').string.split("_")[-1]
            if not ob.pose.string in ["front", "back", "side"]:
                if gtin in drinks or "Freespace" in file_name:
                    crop_rectangle = (int(ob.bndbox.xmin.string), int(ob.bndbox.ymin.string), int(ob.bndbox.xmax.string), int(ob.bndbox.ymax.string))
                    pil_patch = pil_im.crop(crop_rectangle)
                    width, height = pil_patch.size
                    ref_size = 400
                    if width > height:
                        height = int(ref_size * height/width)
                        width = ref_size
                    else:
                        width = int(ref_size * width/height)
                        height = ref_size
                    size = (width, height)
                    pil_patch = pil_patch.resize(size)
                    with img_out:
                        clear_output()
                        display(pil_patch)
                    yield True
                    ob.pose.string = radio.value
                else:
                    ob.pose.string = "front"

        with open(filename, "+w") as f:
            f.write(str(pv.html.body.annotation))
            
        it += 1

img_iter = image_iter()
                    
def on_button_clicked(_):
    next(img_iter)
            
button.on_click(on_button_clicked)
# Out:
# Output()
# Output()
# RadioButtons(description='pose:', options=('front', 'back', 'side'), value='front')
# Button(description='Next', style=ButtonStyle())

# %% [markdown]
# # Rotate Image

# %%
import os
# %matplotlib inline
from matplotlib.pyplot import imshow
import cv2


base_dir = "/content/gdrive/My Drive/Masterarbeit"
object_detection_dir = os.path.join(base_dir, "ObjectDetection")

class FLAGS_OD:
  image_dir = os.path.join(object_detection_dir, "Images")

folder = "gdrive/My Drive/Masterarbeit/ObjectDetection/predict_folder/cleaning"
files = get_xml_files(folder)
     
print(len(files))
for file, path in files:
  print("working on: {}".format(file))
  xml_file = os.path.join(folder,file)
  image = load_annotation(xml_file)
  xml_list = ["<annotation>"]
  height_old = image["size"]["height"]
  rotate_img(image)
  print(image["size"])
  #append_basic(xml_list, image)
  #
  #for obj in image["objects"]:
  #  rotate_box(obj, height_old)
  #  append_obj(xml_list, obj)
  #  print(obj["bndbox"], obj["name"])
 # 
 # xml_list.append("</annotation>")
#
#  with open(xml_file, "w+") as file:
#    file.write("\n".join(xml_list))
# Out:
# 1
# working on: 20190125_114246.xml
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-8144b5ea0be5> in <module>()
#      21   xml_list = ["<annotation>"]
#      22   height_old = image["size"]["height"]
# ---> 23   rotate_img(image)
#      24   print(image["size"])
#      25   #append_basic(xml_list, image)
#
# <ipython-input-5-7f7ef3630ac5> in rotate_img(image)
#       4   img = cv2.imread(image["filename"], 1)
#       5   M = cv2.getRotationMatrix2D((image["size"]["height"]/2,image["size"]["width"]/2), 270, 1)
# ----> 6   rotated = cv2.warpAffine(img, M, (image["size"]["height"] ,image["size"]["width"]))
#       7   cv2.imwrite(image["filename"], img)
#       8
#
# error: OpenCV(3.4.3) /io/opencv/modules/imgproc/src/imgwarp.cpp:2611: error: (-215:Assertion failed) src.cols > 0 && src.rows > 0 in function 'warpAffine'

# %% [markdown]
# # Move Files for Manual Cleaning

# %%
import shutil

name = "ramseier_jusdepomme__50__7610057001078"

dst_dir = "gdrive/My Drive/Masterarbeit/ObjectDetection/predict_folder/cleaning"

files = get_xml_files(FLAGS_OD.image_dir, selected_folders=["_Automat"])
for file, path in files:
  
  xml_file = os.path.join(FLAGS_OD.image_dir, path, file)
  image = load_annotation(xml_file)
  if any([name in obj["name"] for obj in image["objects"]]):
    print("copying: ", file)
    if not xml_file.split(os.sep)[-1] in os.listdir(dst_dir):
      shutil.copy(xml_file, os.path.join(dst_dir, xml_file.split(os.sep)[-1]))
    if not image["filename"].split(os.sep)[-1] in os.listdir(dst_dir):
      shutil.copy(image["filename"], os.path.join(dst_dir, image["filename"].split(os.sep)[-1]))
